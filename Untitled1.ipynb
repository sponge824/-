# %% [markdown]
# <a href="https://colab.research.google.com/github/sponge824/-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/IlliaOvcharenko/lung-segmentation
# %cd lung-segmentation
# Out:
# Cloning into 'lung-segmentation'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 106 (delta 28), reused 12 (delta 12), pack-reused 66 (from 1)
# Receiving objects: 100% (106/106), 164.64 MiB | 17.00 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Updating files: 100% (21/21), done.
# /content/lung-segmentation

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (25.1.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (6.2.0)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (4.4.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (0.4)
# Requirement already satisfied: ipykernel==5.5.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (5.5.6)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (7.34.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: jedi in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (0.19.2)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (3.1.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (1.4.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (4.23.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (7.4.9)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (5.7.2)
# Requirement already satisfied: jupyterlab in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (4.1.5)
# Requirement already satisfied: jupyterlab-server in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (2.27.3)
# Requirement already satisfied: kiwisolver in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 19)) (1.4.8)
# Requirement already satisfied: MarkupSafe in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 20)) (3.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 21)) (3.10.0)
# Requirement already satisfied: mistune in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 22)) (3.1.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 23)) (7.16.6)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 24)) (5.10.4)
# Requirement already satisfied: notebook in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 25)) (6.5.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 26)) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: pandocfilters in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (1.5.1)
# Requirement already satisfied: parso in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 29)) (0.8.4)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 30)) (4.9.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 31)) (0.7.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 32)) (11.1.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 33)) (0.21.1)
# Requirement already satisfied: prompt-toolkit in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 34)) (3.0.50)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 35)) (0.7.0)
# Requirement already satisfied: Pygments in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 36)) (2.18.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 37)) (3.2.1)
# Requirement already satisfied: pyrsistent in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 38)) (0.20.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 39)) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 40)) (2025.1)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 41)) (24.0.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 42)) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 43)) (1.13.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 44)) (1.8.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 45)) (1.17.0)
# Requirement already satisfied: terminado in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 46)) (0.18.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 47)) (0.6.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 48)) (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 49)) (0.20.1+cu124)
# Requirement already satisfied: tornado in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 50)) (6.4.2)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 51)) (5.7.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 52)) (0.2.13)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 53)) (0.5.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython->-r requirements.txt (line 9)) (75.1.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->-r requirements.txt (line 9)) (0.1.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->-r requirements.txt (line 14)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->-r requirements.txt (line 14)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->-r requirements.txt (line 14)) (0.22.3)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.11/dist-packages (from jupyter-client->-r requirements.txt (line 15)) (1.6.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core->-r requirements.txt (line 16)) (4.3.6)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->-r requirements.txt (line 17)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->-r requirements.txt (line 17)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->-r requirements.txt (line 17)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->-r requirements.txt (line 17)) (2.15.0)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->-r requirements.txt (line 17)) (0.2.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from jupyterlab->-r requirements.txt (line 17)) (24.2)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server->-r requirements.txt (line 18)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server->-r requirements.txt (line 18)) (0.10.0)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server->-r requirements.txt (line 18)) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 21)) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 21)) (4.55.8)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert->-r requirements.txt (line 23)) (4.13.3)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert->-r requirements.txt (line 23)) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert->-r requirements.txt (line 23)) (0.10.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->-r requirements.txt (line 24)) (2.21.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook->-r requirements.txt (line 25)) (23.1.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook->-r requirements.txt (line 25)) (1.2.0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 27)) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r requirements.txt (line 42)) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 48)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->-r requirements.txt (line 48)) (1.3.0)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->-r requirements.txt (line 23)) (1.4.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 17)) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 17)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 17)) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->-r requirements.txt (line 17)) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->-r requirements.txt (line 17)) (0.14.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (1.8.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook->-r requirements.txt (line 25)) (21.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->jupyterlab-server->-r requirements.txt (line 18)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->jupyterlab-server->-r requirements.txt (line 18)) (2.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert->-r requirements.txt (line 23)) (2.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.0->jupyterlab->-r requirements.txt (line 17)) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (0.1.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->-r requirements.txt (line 25)) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->-r requirements.txt (line 25)) (2.22)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (3.0.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (24.11.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.11/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 17)) (2.9.0.20241206)

# %%
import torch
import torchvision
import os
import glob
import time
import pickle

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path
from PIL import Image
from sklearn.model_selection import train_test_split

from src.data import LungDataset, blend, Pad, Crop, Resize
from src.models import UNet, PretrainedUNet
from src.metrics import jaccard, dice

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
from google.colab import drive
drive.mount('/content/drive')
data_folder = Path('/content/drive/MyDrive/Visual Information Processing/dataset')
test_folder = Path('/content/drive/MyDrive/Visual Information Processing/dataset/test/img')
origins_folder = data_folder / "images"
masks_folder = data_folder / "masks"
models_folder = Path("models")
images_folder = Path("images")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
batch_size = 4

# %% [markdown]
# Data Loading

# %%
origins_list = [f.stem for f in origins_folder.glob("*.png")]
masks_list = [f.stem for f in masks_folder.glob("*.png")]

# %%
print(len(origins_list))
print(len(masks_list))
# Out:
# 800
# 704

# %%
origin_mask_list = [(mask_name.replace("_mask", ""), mask_name) for mask_name in masks_list]

# %%
split_file = "splits.pk"
if os.path.isfile(split_file):
    with open("splits.pk", "rb") as f:
        splits = pickle.load(f)
else:
    splits = {}
    splits["train"], splits["val"] = train_test_split(origin_mask_list, test_size=0.1, random_state=42)
    #splits["train"], splits["val"] = train_test_split(splits["train"], test_size=0.1, random_state=42)

    splits["test"] = [f.stem for f in test_folder.glob("*.png")]

    with open("splits.pk", "wb") as f:
        pickle.dump(splits, f)

# %%
val_test_transforms = torchvision.transforms.Compose([
    Resize((512, 512)),
])

train_transforms = torchvision.transforms.Compose([
    Pad(200),
    Crop(300),
    val_test_transforms,
])

datasets = {x: LungDataset(
    splits[x],
    origins_folder,
    masks_folder,
    train_transforms if x == "train" else val_test_transforms
) for x in ["train", "test", "val"]}

dataloaders = {x: torch.utils.data.DataLoader(datasets[x], batch_size=batch_size) for x in ["train", "test", "val"]}

# %%
idx = 0
phase = "train"

plt.figure(figsize=(20, 10))
origin, mask = datasets[phase][idx]
pil_origin = torchvision.transforms.functional.to_pil_image(origin + 0.5).convert("RGB")
pil_mask = torchvision.transforms.functional.to_pil_image(mask.float())

plt.subplot(1, 3, 1)
plt.title("origin image")
plt.imshow(np.array(pil_origin))

plt.subplot(1, 3, 2)
plt.title("manually labeled mask")
plt.imshow(np.array(pil_mask))

plt.subplot(1, 3, 3)
plt.title("blended origin + mask")
plt.imshow(np.array(blend(origin, mask)));

plt.savefig(images_folder / "data-example.png", bbox_inches='tight')

# %% [markdown]
# Model training

# %%
# unet = UNet(in_channels=1, out_channels=2, batch_norm=True)
unet = PretrainedUNet(
    in_channels=1,
    out_channels=2,
    batch_norm=True,
    upscale_mode="bilinear"
)
unet
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG11_Weights.IMAGENET1K_V1`. You can also use `weights=VGG11_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# PretrainedUNet(
#   (init_conv): Conv2d(1, 3, kernel_size=(1, 1), stride=(1, 1))
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3s): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4s): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5s): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (center): Block(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dec5): Block(
#     (conv1): Conv2d(768, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dec4): Block(
#     (conv1): Conv2d(768, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dec3): Block(
#     (conv1): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dec2): Block(
#     (conv1): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dec1): Block(
#     (conv1): Conv2d(96, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (out): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
unet = unet.to(device)
# optimizer = torch.optim.SGD(unet.parameters(), lr=0.0005, momentum=0.9)
optimizer = torch.optim.Adam(unet.parameters(), lr=0.0005)

# %%
train_log_filename = "train-log.txt"
epochs = 100
best_val_loss = np.inf
model_name = "unet-6v.pt"

# %%
hist = []

for e in range(epochs):
    start_t = time.time()

    print("train phase")
    unet.train()
    train_loss = 0.0
    for origins, masks in dataloaders["train"]:
        num = origins.size(0)

        origins = origins.to(device)
        masks = masks.to(device)

        optimizer.zero_grad()

        outs = unet(origins)
        softmax = torch.nn.functional.log_softmax(outs, dim=1)
        loss = torch.nn.functional.nll_loss(softmax, masks)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * num
        print(".", end="")

    train_loss = train_loss / len(datasets['train'])
    print()


    print("validation phase")
    unet.eval()
    val_loss = 0.0
    val_jaccard = 0.0
    val_dice = 0.0

    for origins, masks in dataloaders["val"]:
        num = origins.size(0)

        origins = origins.to(device)
        masks = masks.to(device)

        with torch.no_grad():
            outs = unet(origins)
            softmax = torch.nn.functional.log_softmax(outs, dim=1)
            val_loss += torch.nn.functional.nll_loss(softmax, masks).item() * num

            outs = torch.argmax(softmax, dim=1)
            outs = outs.float()
            masks = masks.float()
            val_jaccard += jaccard(masks, outs.float()).item() * num
            val_dice += dice(masks, outs).item() * num

        print(".", end="")
    val_loss = val_loss / len(datasets["val"])
    val_jaccard = val_jaccard / len(datasets["val"])
    val_dice = val_dice / len(datasets["val"])
    print()


    end_t = time.time()
    spended_t = end_t - start_t

    with open(train_log_filename, "a") as train_log_file:
        report = f"epoch: {e+1}/{epochs}, time: {spended_t}, train loss: {train_loss}, \n"\
               + f"val loss: {val_loss}, val jaccard: {val_jaccard}, val dice: {val_dice}"

        hist.append({
            "time": spended_t,
            "train_loss": train_loss,
            "val_loss": val_loss,
            "val_jaccard": val_jaccard,
            "val_dice": val_dice,
        })

        print(report)
        train_log_file.write(report + "\n")

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(unet.state_dict(), models_folder / model_name)
            print("model saved")
            train_log_file.write("model saved\n")
        print()
# Out:
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 1/100, time: 769.4698648452759, train loss: 0.21996633072882468,
# val loss: 0.1518759227974314, val jaccard: 0.8023102367427987, val dice: 0.8868406289060351
# model saved
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 2/100, time: 236.53500366210938, train loss: 0.10326724299369454,
# val loss: 0.12420582141674741, val jaccard: 0.8211903034801215, val dice: 0.8988315026525041
# model saved
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 3/100, time: 235.246506690979, train loss: 0.07460589071303182,
# val loss: 0.0679497791218086, val jaccard: 0.9158306172196294, val dice: 0.9548096698774419
# model saved
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 4/100, time: 234.403990983963, train loss: 0.06981671718059558,
# val loss: 0.06637761133237624, val jaccard: 0.9170971361684127, val dice: 0.9554562467924306
# model saved
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 5/100, time: 234.8111982345581, train loss: 0.060335284790486145,
# val loss: 0.06066667813230568, val jaccard: 0.918755721038496, val dice: 0.9564134847949928
# model saved
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 6/100, time: 235.1217303276062, train loss: 0.05785692320757003,
# val loss: 0.058716547216328095, val jaccard: 0.9227114680787207, val dice: 0.9586489435652612
# model saved
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 7/100, time: 236.37948727607727, train loss: 0.0589056730499906,
# val loss: 0.057826025805003206, val jaccard: 0.9213300120662635, val dice: 0.9578762902340419
# model saved
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 8/100, time: 235.6257107257843, train loss: 0.05386440324675039,
# val loss: 0.058196615480201344, val jaccard: 0.92222433107, val dice: 0.9584417947581116
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 9/100, time: 233.98321342468262, train loss: 0.05275295760135327,
# val loss: 0.05909048713428874, val jaccard: 0.9245523936311963, val dice: 0.9596778355853658
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 10/100, time: 231.29083919525146, train loss: 0.05032922628837362,
# val loss: 0.05605081920052918, val jaccard: 0.9256560701719472, val dice: 0.9603468649823901
# model saved
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 11/100, time: 230.29214453697205, train loss: 0.07023821292094898,
# val loss: 0.08910339818873876, val jaccard: 0.8730947618753138, val dice: 0.9298753469762667
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 12/100, time: 230.41957473754883, train loss: 0.06344450550009666,
# val loss: 0.05873422020337951, val jaccard: 0.9197560179401452, val dice: 0.957024228404945
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 13/100, time: 230.87657856941223, train loss: 0.05659334374794745,
# val loss: 0.06022576053797359, val jaccard: 0.9217090757799821, val dice: 0.9580552611552494
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 14/100, time: 229.70838618278503, train loss: 0.0524271436029748,
# val loss: 0.05829697343665109, val jaccard: 0.9238007387644808, val dice: 0.9592214537338472
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 15/100, time: 232.14627838134766, train loss: 0.05086597866168331,
# val loss: 0.0606409587280851, val jaccard: 0.9176824437060827, val dice: 0.9560721844014987
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 16/100, time: 230.28618836402893, train loss: 0.049345051949199345,
# val loss: 0.05621545866761409, val jaccard: 0.9244304777870715, val dice: 0.9595534969383562
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 17/100, time: 230.42804288864136, train loss: 0.047460704674064456,
# val loss: 0.05971930795152423, val jaccard: 0.9228929751355883, val dice: 0.9587138605789399
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 18/100, time: 230.38000893592834, train loss: 0.04758729042682509,
# val loss: 0.05669792741537094, val jaccard: 0.9252387008196871, val dice: 0.960026526954812
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 19/100, time: 230.17261004447937, train loss: 0.046874632767591434,
# val loss: 0.05732413087512406, val jaccard: 0.9254959519480316, val dice: 0.960185536196534
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 20/100, time: 230.23221945762634, train loss: 0.045947940925968954,
# val loss: 0.06014153990947025, val jaccard: 0.9251352515019161, val dice: 0.9599040511628272
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 21/100, time: 235.0740566253662, train loss: 0.04483103146261608,
# val loss: 0.05503376594311755, val jaccard: 0.9243034879926225, val dice: 0.959483328839423
# model saved
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 22/100, time: 235.6855993270874, train loss: 0.0436515824583846,
# val loss: 0.06107207608055061, val jaccard: 0.9209375985911195, val dice: 0.9573889593003502
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 23/100, time: 235.05752062797546, train loss: 0.045373719903577185,
# val loss: 0.056832745986085544, val jaccard: 0.9215379416103094, val dice: 0.9578891614793053
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 24/100, time: 235.22113633155823, train loss: 0.043303795523741424,
# val loss: 0.053552253460380395, val jaccard: 0.9245652145063373, val dice: 0.9596464432461161
# model saved
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 25/100, time: 235.90794229507446, train loss: 0.04686868667167039,
# val loss: 0.0641331188905407, val jaccard: 0.9156794690750014, val dice: 0.9545852013037238
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 26/100, time: 235.64818382263184, train loss: 0.04478931158051295,
# val loss: 0.06911616971794989, val jaccard: 0.921140409691233, val dice: 0.9575566456351482
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 27/100, time: 236.91491222381592, train loss: 0.0436597959760806,
# val loss: 0.06101876088011433, val jaccard: 0.9250036234587011, val dice: 0.95993078426576
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 28/100, time: 236.91687536239624, train loss: 0.04102644267511123,
# val loss: 0.06121575370640822, val jaccard: 0.9247731843464811, val dice: 0.9598972780603758
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 29/100, time: 235.13695216178894, train loss: 0.042500692550652024,
# val loss: 0.07230848084453126, val jaccard: 0.9230076905707238, val dice: 0.9586263072322792
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 30/100, time: 234.41322135925293, train loss: 0.044410370549225316,
# val loss: 0.06516726776747636, val jaccard: 0.9186445499809694, val dice: 0.9565654355035701
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 31/100, time: 234.29436779022217, train loss: 0.039930051378023,
# val loss: 0.06154855728988916, val jaccard: 0.9225034252018995, val dice: 0.9585252983469359
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 32/100, time: 234.8701410293579, train loss: 0.04628287907248425,
# val loss: 0.06574612729985949, val jaccard: 0.9232641819497229, val dice: 0.9590192882108016
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 33/100, time: 235.15311670303345, train loss: 0.044848804201748325,
# val loss: 0.06524476335502007, val jaccard: 0.9189700014154676, val dice: 0.9566329297885089
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 34/100, time: 234.55364871025085, train loss: 0.05862312340199665,
# val loss: 0.06324170277991766, val jaccard: 0.9216228513650491, val dice: 0.9580809935717516
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 35/100, time: 234.41624569892883, train loss: 0.042822036792128385,
# val loss: 0.06723133747426557, val jaccard: 0.9225473009364705, val dice: 0.9583493017814528
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 36/100, time: 234.8402292728424, train loss: 0.041679577881361445,
# val loss: 0.06182534898250875, val jaccard: 0.9257509825934827, val dice: 0.9603693225014378
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 37/100, time: 235.34215664863586, train loss: 0.03890776079542358,
# val loss: 0.06627626003513873, val jaccard: 0.9246387649589861, val dice: 0.9596566599859319
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 38/100, time: 235.89468622207642, train loss: 0.03735369591610315,
# val loss: 0.062081067180129845, val jaccard: 0.9270569514220869, val dice: 0.9610381663685114
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 39/100, time: 235.1926999092102, train loss: 0.0369021438715441,
# val loss: 0.0726502637418223, val jaccard: 0.9241909141271887, val dice: 0.9594154467045422
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 40/100, time: 235.72890377044678, train loss: 0.036196167096731034,
# val loss: 0.06747547851901659, val jaccard: 0.9277170250113581, val dice: 0.9614804059686796
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 41/100, time: 236.9831359386444, train loss: 0.034731480572519804,
# val loss: 0.07927353973959533, val jaccard: 0.9251424166518198, val dice: 0.9599088531144908
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 42/100, time: 236.51172351837158, train loss: 0.033755751531188614,
# val loss: 0.0740470481170735, val jaccard: 0.9271446332125597, val dice: 0.9611391660193322
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 43/100, time: 236.04915380477905, train loss: 0.03640676613479241,
# val loss: 0.07406029514443706, val jaccard: 0.9201763927097052, val dice: 0.9572286714970226
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 44/100, time: 236.03158235549927, train loss: 0.03381748118777693,
# val loss: 0.0751998332184805, val jaccard: 0.9259784364364516, val dice: 0.9604571839453468
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 45/100, time: 235.42059063911438, train loss: 0.03796818943938467,
# val loss: 0.06610265395171205, val jaccard: 0.9122876390604906, val dice: 0.9524033648867003
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 46/100, time: 235.29982256889343, train loss: 0.03583704661666217,
# val loss: 0.07264709567100229, val jaccard: 0.9231239313810644, val dice: 0.9588683197196101
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 47/100, time: 235.72454166412354, train loss: 0.03254290564371182,
# val loss: 0.08424678791156957, val jaccard: 0.9231790656774816, val dice: 0.9587737002842863
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 48/100, time: 235.6839780807495, train loss: 0.03991808874700307,
# val loss: 0.07087207386191462, val jaccard: 0.9247817707733369, val dice: 0.959833196351226
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 49/100, time: 235.66610765457153, train loss: 0.03327909024876629,
# val loss: 0.07377787511533415, val jaccard: 0.921086309661328, val dice: 0.9578394637980931
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 50/100, time: 235.60716938972473, train loss: 0.032699457600736316,
# val loss: 0.07213946956564003, val jaccard: 0.9262201290735057, val dice: 0.9608507206742193
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 51/100, time: 235.41407370567322, train loss: 0.03210351933794329,
# val loss: 0.0790951187971612, val jaccard: 0.9262827937032135, val dice: 0.9607063187679774
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 52/100, time: 235.20623660087585, train loss: 0.029205314744422787,
# val loss: 0.08241746333283438, val jaccard: 0.9237682802576415, val dice: 0.959247563086765
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 53/100, time: 234.81514048576355, train loss: 0.028651098973790146,
# val loss: 0.07997019872279235, val jaccard: 0.9261302897627924, val dice: 0.9606209582006427
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 54/100, time: 234.42002487182617, train loss: 0.031509912886184537,
# val loss: 0.07423947531152779, val jaccard: 0.9236789354136292, val dice: 0.9591446434947807
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 55/100, time: 235.5101535320282, train loss: 0.03220608897248245,
# val loss: 0.07408221590686852, val jaccard: 0.9252915651025907, val dice: 0.960068833660072
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 56/100, time: 235.18026494979858, train loss: 0.033267913776115876,
# val loss: 0.08456198493359794, val jaccard: 0.9243314115094466, val dice: 0.9595228802989906
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 57/100, time: 235.9015758037567, train loss: 0.028677205731695014,
# val loss: 0.08070981722902244, val jaccard: 0.925311632559333, val dice: 0.9601590465491926
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 58/100, time: 236.9763572216034, train loss: 0.02964545124303108,
# val loss: 0.07250334228008566, val jaccard: 0.9240088009498488, val dice: 0.9595539477509512
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 59/100, time: 237.28731083869934, train loss: 0.030005745327844627,
# val loss: 0.07874725570141429, val jaccard: 0.920656894294309, val dice: 0.9577438033802409
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 60/100, time: 237.48189187049866, train loss: 0.026839536504369776,
# val loss: 0.08585305963183792, val jaccard: 0.9248991986395607, val dice: 0.9600154329353655
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 61/100, time: 237.2303524017334, train loss: 0.025806255666553785,
# val loss: 0.08875481847306373, val jaccard: 0.9251124019354162, val dice: 0.9601126220864309
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 62/100, time: 237.01861548423767, train loss: 0.02497369106447009,
# val loss: 0.09788014089137735, val jaccard: 0.9206717904184906, val dice: 0.9575072997052905
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 63/100, time: 235.8615550994873, train loss: 0.025071727020716028,
# val loss: 0.09718581247077861, val jaccard: 0.9221576099664393, val dice: 0.958363907437929
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 64/100, time: 234.42048048973083, train loss: 0.023986328594786766,
# val loss: 0.0948648838929727, val jaccard: 0.92358673458368, val dice: 0.9592963087726647
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 65/100, time: 235.30776000022888, train loss: 0.02505770327426246,
# val loss: 0.0817862631569446, val jaccard: 0.9197452891040856, val dice: 0.9571025153280983
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 66/100, time: 235.00253200531006, train loss: 0.024924291324276496,
# val loss: 0.09623010173230104, val jaccard: 0.9167421502126775, val dice: 0.9554025362914716
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 67/100, time: 234.97800612449646, train loss: 0.024530078753781923,
# val loss: 0.10187888701616878, val jaccard: 0.915746101191346, val dice: 0.955047929790658
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 68/100, time: 235.84097814559937, train loss: 0.03564543268786034,
# val loss: 0.07440384393426734, val jaccard: 0.9188601777587139, val dice: 0.9565386780550782
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 69/100, time: 234.59505033493042, train loss: 0.027824217238791558,
# val loss: 0.08517831952219278, val jaccard: 0.9227853711222259, val dice: 0.958752518808338
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 70/100, time: 235.1744396686554, train loss: 0.027069469272360605,
# val loss: 0.07170339768201532, val jaccard: 0.9213851119430971, val dice: 0.9581393876545866
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 71/100, time: 234.83252143859863, train loss: 0.02372770722643553,
# val loss: 0.09315299568041949, val jaccard: 0.9211016079069863, val dice: 0.9579112899135536
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 72/100, time: 234.72870254516602, train loss: 0.022090318787837102,
# val loss: 0.10104418283616992, val jaccard: 0.9224443779864782, val dice: 0.9586017366865991
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 73/100, time: 234.8853747844696, train loss: 0.02132849405574102,
# val loss: 0.10222228249193917, val jaccard: 0.9226131153778291, val dice: 0.9587085725555957
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 74/100, time: 236.87940382957458, train loss: 0.02037355468842373,
# val loss: 0.10569917137773943, val jaccard: 0.9216995323208016, val dice: 0.9582294485938381
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 75/100, time: 236.70435738563538, train loss: 0.020845435967295184,
# val loss: 0.09538981538843101, val jaccard: 0.9230238593799968, val dice: 0.9589214333346192
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 76/100, time: 236.3171989917755, train loss: 0.0306352457593638,
# val loss: 0.06962926035196008, val jaccard: 0.920817170344608, val dice: 0.9577107034938436
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 77/100, time: 236.90108609199524, train loss: 0.02946635742788019,
# val loss: 0.09691503664977114, val jaccard: 0.9198363473717596, val dice: 0.9570597040821129
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 78/100, time: 238.0683023929596, train loss: 0.023009502971883256,
# val loss: 0.0978559243007445, val jaccard: 0.9213134923451384, val dice: 0.9579834786938949
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 79/100, time: 236.97471380233765, train loss: 0.02082175911090809,
# val loss: 0.10514836768868943, val jaccard: 0.9214918059362492, val dice: 0.9580974595647462
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 80/100, time: 236.71310091018677, train loss: 0.020084994704584705,
# val loss: 0.11079929643113848, val jaccard: 0.9210871726694242, val dice: 0.9578489761956981
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 81/100, time: 236.31407761573792, train loss: 0.02074648205067309,
# val loss: 0.10746098467161957, val jaccard: 0.9178498840667833, val dice: 0.9560082000745854
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 82/100, time: 236.7055606842041, train loss: 0.019479653796572443,
# val loss: 0.10832083519075958, val jaccard: 0.9206848597862352, val dice: 0.9576261992185888
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 83/100, time: 236.98158359527588, train loss: 0.018989184930167304,
# val loss: 0.1102861320258866, val jaccard: 0.9205299540304802, val dice: 0.9575245917682916
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 84/100, time: 237.01941204071045, train loss: 0.019202053192326148,
# val loss: 0.11719353601966105, val jaccard: 0.9193979837525059, val dice: 0.9568268681915713
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 85/100, time: 236.77093696594238, train loss: 0.019473413555731327,
# val loss: 0.11521078551739035, val jaccard: 0.9190736404606994, val dice: 0.9566619144359105
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 86/100, time: 237.3037989139557, train loss: 0.019381492417805943,
# val loss: 0.11420873919842948, val jaccard: 0.9202235827983265, val dice: 0.9573937981901034
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 87/100, time: 237.03533244132996, train loss: 0.01893968354339754,
# val loss: 0.12457620761763881, val jaccard: 0.9161190231081465, val dice: 0.9550948596336473
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 88/100, time: 237.6613690853119, train loss: 0.018753155602486495,
# val loss: 0.11932528585615293, val jaccard: 0.9179785318777595, val dice: 0.9561477949921514
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 89/100, time: 237.24023842811584, train loss: 0.017999670119576545,
# val loss: 0.11984013293830442, val jaccard: 0.9185361190580986, val dice: 0.9563714484093895
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 90/100, time: 237.5155508518219, train loss: 0.02242297571782158,
# val loss: 0.09352038727259972, val jaccard: 0.9167958850591955, val dice: 0.9553570932065937
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 91/100, time: 236.58854842185974, train loss: 0.031476207177550494,
# val loss: 0.09282526247937914, val jaccard: 0.916862985617678, val dice: 0.9552799127471279
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 92/100, time: 236.71378564834595, train loss: 0.025112538898619714,
# val loss: 0.09405585357420881, val jaccard: 0.9171863357785722, val dice: 0.9555327841933344
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 93/100, time: 236.643958568573, train loss: 0.020120525091156763,
# val loss: 0.10830636532373832, val jaccard: 0.9180007249536649, val dice: 0.9560891381451782
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 94/100, time: 236.23989248275757, train loss: 0.017397190239662998,
# val loss: 0.11100189314341881, val jaccard: 0.9218713129070443, val dice: 0.9582852947879845
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 95/100, time: 237.41130113601685, train loss: 0.016425071163529658,
# val loss: 0.11543277210332978, val jaccard: 0.9199820723332149, val dice: 0.9572332442646295
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 96/100, time: 235.5310080051422, train loss: 0.016109303706641917,
# val loss: 0.118676230626207, val jaccard: 0.9199020610728734, val dice: 0.9571582448314613
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 97/100, time: 235.29948496818542, train loss: 0.015782731546951225,
# val loss: 0.12130632923102715, val jaccard: 0.9206147336624038, val dice: 0.9575479316039824
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 98/100, time: 235.12092351913452, train loss: 0.015628842997407365,
# val loss: 0.12235700979199209, val jaccard: 0.920125340072202, val dice: 0.9572665733350835
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 99/100, time: 235.13099241256714, train loss: 0.015816521170250425,
# val loss: 0.12875906619387614, val jaccard: 0.918357748380849, val dice: 0.9562123971925655
#
# train phase
# ...............................................................................................................................................................
# validation phase
# ..................
# epoch: 100/100, time: 235.47179675102234, train loss: 0.016375348581027644,
# val loss: 0.12797198024853854, val jaccard: 0.9206469503926559, val dice: 0.9575769716585186
